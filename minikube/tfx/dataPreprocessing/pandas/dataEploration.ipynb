# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import json

# Read json stop and searches
# https://data.police.uk/docs/method/stops-force/

filePath = r'C:\Users\Pasca\OneDrive\Desktop\tensorflow\delateExploration\dataProcessing\dataByForce.json'

df = pd.read_json(filePath, orient='columns')

# %%
df
# Out:
#        age_range                          outcome  involved_person  \
# 0          10-17                           Arrest             True
# 1          10-17     A no further action disposal             True
# 2          10-17     A no further action disposal             True
# 3          25-34     A no further action disposal             True
# 4          10-17         Khat or Cannabis warning             True
# ...          ...                              ...              ...
# 422515     18-24     A no further action disposal             True
# 422516   over 34     A no further action disposal             True
# 422517     18-24  Caution (simple or conditional)             True
# 422518     18-24  Caution (simple or conditional)             True
# 422519     10-17     A no further action disposal             True
#
#                                    self_defined_ethnicity  gender  \
# 0                         Other ethnic group - Not stated    Male
# ...

# %%
df.shape
# Out:
# (422520, 17)

# %%
# Info about the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422520 entries, 0 to 422519
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   age_range                            367229 non-null  object
#  1   outcome                              422520 non-null  object
#  2   involved_person                      422520 non-null  bool
#  3   self_defined_ethnicity               403153 non-null  object
#  4   gender                               402449 non-null  object
#  5   legislation                          402215 non-null  object
#  6   outcome_linked_to_object_of_search   125464 non-null  float64
#  7   datetime                             422520 non-null  datetime64[ns, UTC]
#  8   removal_of_more_than_outer_clothing  173272 non-null  float64
#  9   outcome_object                       422520 non-null  object
# ...

# %%
df.describe()
# Out:
#        outcome_linked_to_object_of_search  \
# count                       125464.000000
# mean                             0.420623
# std                              0.493661
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              1.000000
# max                              1.000000
#
#        removal_of_more_than_outer_clothing      operation  operation_name
# count                        173272.000000  285836.000000             0.0
# mean                              0.036728       0.034674             NaN
# std                               0.188095       0.182952             NaN
# min                               0.000000       0.000000             NaN
# 25%                               0.000000       0.000000             NaN
# 50%                               0.000000       0.000000             NaN
# ...

# %%
# types of the dataset

df.dtypes
# Out:
# age_range                                           object
# outcome                                             object
# involved_person                                       bool
# self_defined_ethnicity                              object
# gender                                              object
# legislation                                         object
# outcome_linked_to_object_of_search                 float64
# datetime                               datetime64[ns, UTC]
# removal_of_more_than_outer_clothing                float64
# outcome_object                                      object
# location                                            object
# operation                                          float64
# officer_defined_ethnicity                           object
# type                                                object
# operation_name                                     float64
# object_of_search                                    object
# ...

# %%
df.isnull().any()
# Out:
# age_range                               True
# outcome                                False
# involved_person                        False
# self_defined_ethnicity                  True
# gender                                  True
# legislation                             True
# outcome_linked_to_object_of_search      True
# datetime                               False
# removal_of_more_than_outer_clothing     True
# outcome_object                         False
# location                                True
# operation                               True
# officer_defined_ethnicity               True
# type                                   False
# operation_name                          True
# object_of_search                        True
# force                                  False
# dtype: bool

# %%
# numbers of null values in each column

df.isnull().sum()
# Out:
# age_range                               55291
# outcome                                     0
# involved_person                             0
# self_defined_ethnicity                  19367
# gender                                  20071
# legislation                             20305
# outcome_linked_to_object_of_search     297056
# datetime                                    0
# removal_of_more_than_outer_clothing    249248
# outcome_object                              0
# location                                75063
# operation                              136684
# officer_defined_ethnicity               34820
# type                                        0
# operation_name                         422520
# object_of_search                        56374
# force                                       0
# dtype: int64

# %%
# Shows how much % of the data per column is null

df.isnull().sum() / df.shape[0]
# Out:
# age_range                              0.130860
# outcome                                0.000000
# involved_person                        0.000000
# self_defined_ethnicity                 0.045837
# gender                                 0.047503
# legislation                            0.048057
# outcome_linked_to_object_of_search     0.703058
# datetime                               0.000000
# removal_of_more_than_outer_clothing    0.589908
# outcome_object                         0.000000
# location                               0.177655
# operation                              0.323497
# officer_defined_ethnicity              0.082410
# type                                   0.000000
# operation_name                         1.000000
# object_of_search                       0.133423
# force                                  0.000000
# dtype: float64

# %%
# columns of the dataset 

df.columns
# Out:
# Index(['age_range', 'outcome', 'involved_person', 'self_defined_ethnicity',
#        'gender', 'legislation', 'outcome_linked_to_object_of_search',
#        'datetime', 'removal_of_more_than_outer_clothing', 'outcome_object',
#        'location', 'operation', 'officer_defined_ethnicity', 'type',
#        'operation_name', 'object_of_search', 'force'],
#       dtype='object')

# %%
# distribution of gender
df['gender'].value_counts()
# Out:
# Male      361040
# Female     40374
# Other       1035
# Name: gender, dtype: int64

# %%
# age range 

df['age_range'].value_counts()
# Out:
# 18-24       128088
# 25-34        91319
# over 34      82122
# 10-17        65492
# under 10       208
# Name: age_range, dtype: int64

# %%
# ethnic categories => The self-defined ethnicity of the person stopped

df['self_defined_ethnicity'].value_counts()
# Out:
# White - English/Welsh/Scottish/Northern Irish/British                                   182763
# Other ethnic group - Not stated                                                          75335
# White - Any other White background                                                       30309
# Black/African/Caribbean/Black British - Any other Black/African/Caribbean background     25008
# Asian/Asian British - Any other Asian background                                         16804
# Black/African/Caribbean/Black British - African                                          16781
# Black/African/Caribbean/Black British - Caribbean                                        11254
# Asian/Asian British - Pakistani                                                          10764
# Other ethnic group - Any other ethnic group                                               6883
# Asian/Asian British - Bangladeshi                                                         6429
# ...

# %%
# ethnic categories => The officer-defined ethnicity of the person stopped

df.officer_defined_ethnicity.value_counts()
# Out:
# White    241195
# Black     81262
# Asian     50607
# Other     13231
# Mixed      1405
# Name: officer_defined_ethnicity, dtype: int64

# %%
df['outcome'].value_counts()
# Out:
# A no further action disposal       309281
# Arrest                              51618
# Community resolution                31158
# Summons / charged by post            8466
# Penalty Notice for Disorder          8145
#                                      6756
# Khat or Cannabis warning             5525
# Caution (simple or conditional)      1571
# Name: outcome, dtype: int64

# %%
# How much % is null => only 1,5%

df.outcome.value_counts() / df.type.notnull().sum()
# Out:
# A no further action disposal       0.731991
# Arrest                             0.122167
# Community resolution               0.073743
# Summons / charged by post          0.020037
# Penalty Notice for Disorder        0.019277
#                                    0.015990
# Khat or Cannabis warning           0.013076
# Caution (simple or conditional)    0.003718
# Name: outcome, dtype: float64

# %%
df['object_of_search'].value_counts()
# Out:
# Controlled drugs                              234558
# Offensive weapons                              51092
# Stolen goods                                   31633
# Article for use in theft                       18368
# Evidence of offences under the Act              9452
# Articles for use in criminal damage             8665
# Anything to threaten or harm anyone             7249
# Firearms                                        2784
# Fireworks                                       1489
# Psychoactive substances                          529
# Game or poaching equipment                       126
# Detailed object of search unavailable             82
# Goods on which duty has not been paid etc.        59
# Evidence of wildlife offences                     24
# Crossbows                                         20
# dog                                               14
# Seals or hunting equipment                         2
# Name: object_of_search, dtype: int64

# %%
# shows the forces in the dataframe
# force = county

df['force'].value_counts()
# Out:
# metropolitan          175059
# merseyside             32604
# thames-valley          14369
# west-yorkshire         14005
# essex                  13516
# south-yorkshire        12157
# kent                   10859
# south-wales            10653
# btp                     9939
# lancashire              8874
# hampshire               8650
# avon-and-somerset       6931
# west-midlands           6800
# hertfordshire           6691
# sussex                  5775
# humberside              5594
# surrey                  5477
# devon-and-cornwall      5247
# cleveland               5230
# staffordshire           4511
# cheshire                4211
# west-mercia             3929
# leicestershire          3628
# norfolk                 3459
# nottinghamshire         3385
# northumbria             3351
# gwent                   3240
# north-wales             3126
# bedfordshire            2686
# northamptonshire        2646
# suffolk                 2529
# cambridgeshire          2501
# ...

# %%
df
# Out:
#        age_range                          outcome  involved_person  \
# 0          10-17                           Arrest             True
# 1          10-17     A no further action disposal             True
# 2          10-17     A no further action disposal             True
# 3          25-34     A no further action disposal             True
# 4          10-17         Khat or Cannabis warning             True
# ...          ...                              ...              ...
# 422515     18-24     A no further action disposal             True
# 422516   over 34     A no further action disposal             True
# 422517     18-24  Caution (simple or conditional)             True
# 422518     18-24  Caution (simple or conditional)             True
# 422519     10-17     A no further action disposal             True
#
#                                    self_defined_ethnicity  gender  \
# 0                         Other ethnic group - Not stated    Male
# ...

# %%
# Cleanup of the DataFrame. All null values in the columns are deleted

# df.drop(df.)
df_cleared = df.dropna(subset=['operation', 'operation_name'])

# df_cleared = df[df.age_range.notna() & df.gender.notna() & df.officer_defined_ethnicity.notna() & df.self_defined_ethnicity.notna() & df.object_of_search.notna() & df.location.notna() & df.legislation.notna()]

# %%
df_cleared
# Out:
# Empty DataFrame
# Columns: [age_range, outcome, involved_person, self_defined_ethnicity, gender, legislation, outcome_linked_to_object_of_search, datetime, removal_of_more_than_outer_clothing, outcome_object, location, operation, officer_defined_ethnicity, type, operation_name, object_of_search, force]
# Index: []

# %%
df_cleared.isnull().any()
# Out:
# age_range                              False
# outcome                                False
# involved_person                        False
# self_defined_ethnicity                 False
# gender                                 False
# legislation                            False
# outcome_linked_to_object_of_search      True
# datetime                               False
# removal_of_more_than_outer_clothing     True
# outcome_object                         False
# location                               False
# operation                               True
# officer_defined_ethnicity              False
# type                                   False
# operation_name                          True
# object_of_search                       False
# force                                  False
# dtype: bool

# %%
df_cleared
# Out:
#        age_range                          outcome  involved_person  \
# 1          10-17     A no further action disposal             True
# 3          25-34     A no further action disposal             True
# 4          10-17         Khat or Cannabis warning             True
# 5        over 34                           Arrest             True
# 6          10-17     A no further action disposal             True
# ...          ...                              ...              ...
# 422514     18-24  Caution (simple or conditional)             True
# 422515     18-24     A no further action disposal             True
# 422516   over 34     A no further action disposal             True
# 422517     18-24  Caution (simple or conditional)             True
# 422519     10-17     A no further action disposal             True
#
#                                    self_defined_ethnicity  gender  \
# 1       White - English/Welsh/Scottish/Northern Irish/...  Female
# ...

# %%
df_cleared.age_range.unique()
# Out:
# array(['10-17', '25-34', 'over 34', '18-24', 'under 10'], dtype=object)

# %%
# # encode dataframe
labelEncoder = LabelEncoder()

# #Column gender
# labelEncoder.fit(['Male','Female', 'Other'])
# df_cleared.gender = labelEncoder.fit_transform(df_cleared.gender)

# #Column age_range
# labelEncoder.fit(['18-24','25-34', 'over 34', 'under 10'])
# df_cleared.age_range = labelEncoder.fit_transform(df_cleared.age_range)

# #Column force
# labelEncoder.fit(['avon-and-somerset', 'bedfordshire', 'btp', 'cambridgeshire',
#        'cheshire', 'city-of-london', 'cleveland', 'cumbria', 'derbyshire',
#        'devon-and-cornwall', 'dorset', 'durham', 'dyfed-powys', 'essex',
#        'gloucestershire', 'hertfordshire', 'humberside', 'kent',
#        'lancashire', 'leicestershire', 'norfolk', 'north-wales',
#        'north-yorkshire', 'northamptonshire', 'northumbria',
#        'nottinghamshire', 'south-yorkshire', 'staffordshire', 'suffolk',
#        'surrey', 'sussex', 'thames-valley', 'warwickshire', 'west-mercia',
#        'west-yorkshire', 'hampshire', 'lincolnshire', 'merseyside',
#        'metropolitan', 'wiltshire'])
# df_cleared.force = labelEncoder.fit_transform(df_cleared.force)

# #Column object_of_search
# labelEncoder.fit(['Articles for use in criminal damage', 'Offensive weapons',
#        'Controlled drugs', 'Stolen goods', 'Article for use in theft', 'Firearms', 'Fireworks',
#        'Anything to threaten or harm anyone',
#        'Evidence of offences under the Act', 'Psychoactive substances',
#        'Game or poaching equipment',
#        'Detailed object of search unavailable',
#        'Evidence of wildlife offences', 'Seals or hunting equipment',
#        'Goods on which duty has not been paid etc.', 'dog', 'Crossbows'])
# df_cleared.object_of_search = labelEncoder.fit_transform(df_cleared.object_of_search)

# #Column officer_defined_ethnicity
# labelEncoder.fit(['White', 'Asian', 'Mixed', 'Black', 'Other'])
# df_cleared.officer_defined_ethnicity = labelEncoder.fit_transform(df_cleared.officer_defined_ethnicity)

# #Column self_defined_ethnicity
# labelEncoder.fit(['White - English/Welsh/Scottish/Northern Irish/British',
#        'Other ethnic group - Not stated',
#        'White - Any other White background',
#        'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#        'Other ethnic group - Any other ethnic group',
#        'Black/African/Caribbean/Black British - Caribbean',
#        'Black/African/Caribbean/Black British - African', 'White - Irish',
#        'Mixed/Multiple ethnic groups - White and Asian',
#        'Mixed/Multiple ethnic groups - White and Black Caribbean',
#        'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#        'Asian/Asian British - Any other Asian background',
#        'Asian/Asian British - Pakistani', 'Asian/Asian British - Indian',
#        'Other ethnic group - Arab', 'Asian/Asian British - Bangladeshi',
#        'Asian/Asian British - Chinese',
#        'Mixed/Multiple ethnic groups - White and Black African',
#        'White - Gypsy or Irish Traveller'])
# df_cleared.self_defined_ethnicity = labelEncoder.fit_transform(df_cleared.self_defined_ethnicity)

# #Column type
# labelEncoder.fit(['Person search', 'Person and Vehicle search', 'Vehicle search'])
# df_cleared.type = labelEncoder.fit_transform(df_cleared.type)

# #Column legislation
# labelEncoder.fit(['Police and Criminal Evidence Act 1984 (section 1)',
#        'Misuse of Drugs Act 1971 (section 23)',
#        'Firearms Act 1968 (section 47)',
#        'Psychoactive Substances Act 2016 (s36(2))',
#        'Criminal Justice Act 1988 (section 139B)',
#        'Poaching Prevention Act 1862 (section 2)',
#        'Criminal Justice and Public Order Act 1994 (section 60)',
#        'Police and Criminal Evidence Act 1984 (section 6)',
#        'Crossbows Act 1987 (section 4)',
#        'Customs and Excise Management Act 1979 (section 163)',
#        'Hunting Act 2004 (section 8)',
#        'Protection of Badgers Act 1992 (section 11)',
#        'Deer Act 1991 (section 12)',
#        'Aviation Security Act 1982 (section 27(1))',
#        'Conservation of Seals Act 1970 (section 4)',
#        'Public Stores Act 1875 (section 6)',
#        'Wildlife and Countryside Act 1981 (section 19)',
#        'Environmental Protection Act 1990 (section 34B )'])
# df_cleared.legislation = labelEncoder.fit_transform(df_cleared.legislation)

#Column involved_person
labelEncoder.fit([True, False])
df_cleared.involved_person = labelEncoder.fit_transform(df_cleared.involved_person)
# Out:
# C:\Users\Pasca\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_cleared.iloc[2].location['street']['id']
# Out:
# 542837

# %%
df_cleared
# Out:
#        age_range                          outcome  involved_person  \
# 1          10-17     A no further action disposal                1
# 3          25-34     A no further action disposal                1
# 4          10-17         Khat or Cannabis warning                1
# 5        over 34                           Arrest                1
# 6          10-17     A no further action disposal                1
# ...          ...                              ...              ...
# 422514     18-24  Caution (simple or conditional)                1
# 422515     18-24     A no further action disposal                1
# 422516   over 34     A no further action disposal                1
# 422517     18-24  Caution (simple or conditional)                1
# 422519     10-17     A no further action disposal                1
#
#                                    self_defined_ethnicity  gender  \
# 1       White - English/Welsh/Scottish/Northern Irish/...  Female
# ...

# %%
# Split the DataFrame into noAction = 0 and Action = 1

df_noAction = df_cleared[df_cleared.outcome.isin(['A no further action disposal'])]
df_noAction.insert(loc=1, column='action', value=0)

df_Action = df_cleared[df_cleared.outcome.isin(['Arrest', 'Community resolution', 'Summons / charged by post', 'Penalty Notice for Disorder', 'Khat or Cannabis warning', 'Caution (simple or conditional)'])]
df_Action.insert(loc=1, column='action', value=1)

df_cleared = pd.concat([df_noAction, df_Action])

# %%
df_cleared
# Out:
#        age_range  action                          outcome  involved_person  \
# 1          10-17       0     A no further action disposal                1
# 3          25-34       0     A no further action disposal                1
# 6          10-17       0     A no further action disposal                1
# 7        over 34       0     A no further action disposal                1
# 8        over 34       0     A no further action disposal                1
# ...          ...     ...                              ...              ...
# 422492     18-24       1  Caution (simple or conditional)                1
# 422504     25-34       1                           Arrest                1
# 422513     18-24       1  Caution (simple or conditional)                1
# 422514     18-24       1  Caution (simple or conditional)                1
# 422517     18-24       1  Caution (simple or conditional)                1
#
#                                    self_defined_ethnicity  gender  \
# ...

# %%
# Create a new column with the locationID

df_cleared['locationId'] = df_cleared.location.apply(lambda x : x['street']['id'] if isinstance(x, dict) else x)

# %%
df_cleared.locationId
# Out:
# 1       537252.0
# 3       528649.0
# 6       542837.0
# 7       542741.0
# 8       528116.0
#           ...
# 1903         NaN
# 1909         NaN
# 1913         NaN
# 1918         NaN
# 1929         NaN
# Name: locationId, Length: 236221, dtype: float64

# %%
# Normalize DataFrame 

df_normalize = df_cleared.drop(['outcome','outcome_linked_to_object_of_search', 'datetime', 'removal_of_more_than_outer_clothing', 'outcome_object',  'operation', 'operation_name', 'location'], axis=1)

# %%
df_normalize.columns

# %%
df_normalize

# %%
# Normalize data set

column_maxes = df_normalize.max()
df_max = column_maxes.max()
df_normalized = df_normalize / df_max

# %%
df_normalized

# %%
corrMatrix = df_normalized.corr()
corrMatrix

# %%
df_normalized.describe()

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

x = np.array(df_normalized.officer_defined_ethnicity)
y = np.array(df_normalized.self_defined_ethnicity)
plt.scatter(x, y, alpha=0.5)
m, b = np.polyfit(x, y, 1)
plt.plot(x,m*x + b)

# %%
# Verteilung der Altersgruppen

plt.hist(df_normalized.age_range)
plt.show()

# %%
# Anzahl officer pro Ethnie

print(df_normalized.officer_defined_ethnicity.value_counts()) 

plt.hist(df_cleared.officer_defined_ethnicity)
plt.show()

# %%
# Histogramm Forces

plt.hist(df_cleared.force)
fig = plt.gcf()
fig.set_size_inches(30, 10.5)
plt.show()

# %%
gender_column = df_cleared.gender

df_cleared.groupby(['action', gender_column]).size().unstack(level=1).plot(kind = 'bar')

plt.ylabel('numbers')

# %%
ethnicOfficer_column = df_cleared.officer_defined_ethnicity

df_cleared.groupby(['action', ethnicOfficer_column]).size().unstack(level=1).plot(kind = 'bar')

plt.ylabel('numbers')

# %%
def histogram_intersection(a, b):
    v = np.minimum(a, b).sum().round(decimals=1)
    return v

df_normalized.corr(method=histogram_intersection)
