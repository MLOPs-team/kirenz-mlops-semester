# %%
pip install apache-beam[interactive]
# Out:
# ...
#      |████████████████████████████████| 112 kB 20.7 MB/s eta 0:00:01
# ...
#   Created wheel for timeloop: filename=timeloop-1.0.2-py3-none-any.whl size=3720 sha256=9923676f970714f561be996e429fb42360a24d7faaa8b1ccd6b04db58fd258a9
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/c0/da/aa/ba3dfa0f64d081837addfa435f40349943bca72a79d5b08b01
# Successfully built timeloop
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 7.1.0
#     Uninstalling jupyter-client-7.1.0:
#       Successfully uninstalled jupyter-client-7.1.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import tensorflow_data_validation as tfdv

eval_stats = tfdv.generate_statistics_from_tfrecord(data_location= 'tfx/pipelines/police-uk-pipeline/CsvExampleGen/examples/2/Split-eval/data_tfrecord-00003-of-00004.gz')
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.6 interpreter.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tfx/lib/python3.6/site-packages/tensorflow_data_validation/utils/stats_util.py:247: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tfx/lib/python3.6/site-packages/tensorflow_data_validation/utils/stats_util.py:247: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
tfdv.visualize_statistics(eval_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
train_stats = tfdv.generate_statistics_from_tfrecord(data_location= 'tfx/pipelines/police-uk-pipeline/CsvExampleGen/examples/2/Split-train/data_tfrecord-00003-of-00004.gz')
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.6 interpreter.

# %%
 tfdv.visualize_statistics(train_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
 schema = tfdv.infer_schema(eval_stats)
 tfdv.display_schema(schema)
# Out:
#                               Type  Presence Valency Domain
# Feature name
# ''                             INT  required              -
# 'action'                     FLOAT  required              -
# 'age_range'                  FLOAT  required              -
# 'day'                        FLOAT  required              -
# 'force'                      FLOAT  required              -
# 'gender'                     FLOAT  required              -
# 'involved_person'            FLOAT  required              -
# 'legislation'                FLOAT  required              -
# 'locationId'                 FLOAT  required              -
# 'month'                      FLOAT  required              -
# 'object_of_search'           FLOAT  required              -
# 'officer_defined_ethnicity'  FLOAT  required              -
# 'self_defined_ethnicity'     FLOAT  required              -
# 'type'                       FLOAT  required              -
# ...

# %%
print(schema)
# Out:
# feature {
#   name: ""
#   type: INT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "action"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "age_range"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "day"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "force"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "gender"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-8a6941c44c78> in <module>
#       1 import tensorflow as tf
#       2 import tensorflow_data_validation as tfdv
# ----> 3 stats = tfdv.generate_statistics_from_csv(data_location='/home/ec2-user/police/data/simple/data.gzip', encoding= 'unicode_escape')
#
# TypeError: generate_statistics_from_csv() got an unexpected keyword argument 'encoding'
