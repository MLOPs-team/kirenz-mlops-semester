# %%
# !pip install tfx-bsl==1.3.0
# !pip install tensorflow-model-analysis==0.34.1
# Out:
# ERROR: Could not find a version that satisfies the requirement tfx-bsl==1.3.0 (from versions: none)
# ERROR: No matching distribution found for tfx-bsl==1.3.0
# ...
#   Using cached tensorflow_model_analysis-0.34.1-py3-none-any.whl (1.8 MB)
# ...
#   Using cached pyarrow-2.0.0.tar.gz (58.9 MB)
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/ec2-user/anaconda3/bin/python /tmp/pip-standalone-pip-1erqyo6j/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-6q39ucqv/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- 'cython >= 0.29' 'numpy==1.14.5; python_version<'"'"'3.7'"'"'' 'numpy==1.16.0; python_version>='"'"'3.7'"'"'' setuptools setuptools_scm wheel
#        cwd: None
#   Complete output (3209 lines):
#   Ignoring numpy: markers 'python_version < "3.7"' don't match your environment
# ...

# %%
import tensorflow_model_analysis as tfma

eval_result = tfma.load_eval_result('/home/ec2-user/tfx/pipelines/police-uk-pipeline/Evaluator/evaluation/299')
#print(eval_result)
#tfma.view.render_plot(eval_result)
tfma.view.render_slicing_metrics(eval_result)
# Out:
# SlicingMetricsViewer(config={'weightedExamplesColumn': 'example_count'}, data=[{'slice': 'Overall', 'metrics':…
